# %% [markdown]
# <a href="https://colab.research.google.com/github/AdairGarcia/Semillero-IA-hitss/blob/main/Teoria/Clase02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase 2 - Conceptos
#
# ![image.png](data:image/png;base64,...)
#
# 1.  SSE: Suma de Cuadrados de los Errores/Residuos (Sum of Squared Errors)
#
# Mide la porción de la variabilidad total que NO es explicada por el modelo. Representa el error de predicción del modelo, también conocido como "residuo". Es la diferencia entre lo que observaste y lo que tu modelo predijo.
#
#
# 2. SSR: Suma de Cuadrados de la Regresión (Regression Sum of Squares)
#
# Mide la porción de la variabilidad total que es explicada por el modelo de regresión lineal. Representa la mejora en la predicción que obtienes al usar la línea de regresión (ŷ) en lugar de simplemente usar el promedio (ȳ).
#
#
# 3. Syy: Suma de Cuadrados de la Variabilidad Total (Total Sum of Squares)
#
# Mide la variación total de los datos observados (yₖ) con respecto a su media (ȳ). Imagina que no tienes un modelo de regresión y tu única opción para predecir cualquier valor de y es usar el promedio de todos los datos. La Syy representa el error total que cometerías al hacer eso.

# %% [markdown]
# # ¿Por qué se utilizan estás metrícas?
#
# Se utilizan para responder a dos preguntas cruciales sobre tu modelo
# 1. ¿Qué tan bueno es el ajuste del modelo?
# 2. ¿Es el modelo estadísticamente significativo?
